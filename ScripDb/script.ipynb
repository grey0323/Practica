-- %% [markdown]
-- # [ApiResume]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ApiResume]    Script Date: 01/09/2023 15:24:54 ******/
CREATE DATABASE [ApiResume]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ApiResume', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\ApiResume.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ApiResume_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\ApiResume_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ApiResume] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ApiResume].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ApiResume] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ApiResume] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ApiResume] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ApiResume] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ApiResume] SET ARITHABORT OFF 
GO
ALTER DATABASE [ApiResume] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ApiResume] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ApiResume] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ApiResume] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ApiResume] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ApiResume] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ApiResume] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ApiResume] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ApiResume] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ApiResume] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ApiResume] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ApiResume] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ApiResume] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ApiResume] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ApiResume] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ApiResume] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ApiResume] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ApiResume] SET RECOVERY FULL 
GO
ALTER DATABASE [ApiResume] SET  MULTI_USER 
GO
ALTER DATABASE [ApiResume] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ApiResume] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ApiResume] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ApiResume] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ApiResume] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ApiResume] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ApiResume', N'ON'
GO
ALTER DATABASE [ApiResume] SET QUERY_STORE = ON
GO
ALTER DATABASE [ApiResume] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Datos]

-- %%
USE [ApiResume]
GO

-- %%
/****** Object:  Table [dbo].[Datos]    Script Date: 01/09/2023 15:24:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Datos](
	[id] [int] NOT NULL,
	[link] [varchar](max) NOT NULL,
	[title] [varchar](max) NOT NULL,
	[content] [varchar](max) NOT NULL,
	[date] [datetime] NOT NULL,
 CONSTRAINT [PK_Dates] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [ApiResume]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ApiResume] SET  READ_WRITE 
GO
